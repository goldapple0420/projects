# %%
# !pip install BeautifulSoup4
# !pip install cssselect
# !pip install pymysql
# !pip install cursor
# !pip install selenium
# !pip install fake-useragent
# Out:
# Requirement already satisfied: BeautifulSoup4 in c:\users\sce\anaconda3\lib\site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\sce\anaconda3\lib\site-packages (from BeautifulSoup4) (2.2.1)
# Collecting cssselect
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Installing collected packages: cssselect
# Successfully installed cssselect-1.1.0
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2
# Collecting cursor
#   Downloading cursor-1.3.5.tar.gz (15 kB)
# Building wheels for collected packages: cursor
#   Building wheel for cursor (setup.py): started
#   Building wheel for cursor (setup.py): finished with status 'done'
#   Created wheel for cursor: filename=cursor-1.3.5-py3-none-any.whl size=15844 sha256=e46b56f58c9dcf6e1ce5e40238dfce32f33d9d836ef6e795aa34b2f250a40b9d
#   Stored in directory: c:\users\sce\appdata\local\pip\cache\wheels\0a\1e\20\76ffee693263edcc260e83ecd320c67e46020f908246f8a411
# Successfully built cursor
# Installing collected packages: cursor
# Successfully installed cursor-1.3.5
# Collecting selenium
#   Downloading selenium-4.3.0-py3-none-any.whl (981 kB)
# Collecting trio-websocket~=0.9
#   Downloading trio_websocket-0.9.2-py3-none-any.whl (16 kB)
# Collecting trio~=0.17
#   Downloading trio-0.21.0-py3-none-any.whl (358 kB)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in c:\users\sce\anaconda3\lib\site-packages (from selenium) (1.26.7)
# Requirement already satisfied: idna in c:\users\sce\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.2)
# Requirement already satisfied: sortedcontainers in c:\users\sce\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\sce\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\sce\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\sce\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.14.6)
# Collecting outcome
#   Downloading outcome-1.2.0-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\sce\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.2.0)
# Requirement already satisfied: pycparser in c:\users\sce\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.20)
# Collecting wsproto>=0.14
#   Downloading wsproto-1.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\sce\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pyOpenSSL>=0.14 in c:\users\sce\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (21.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in c:\users\sce\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (3.4.8)
# Requirement already satisfied: certifi in c:\users\sce\anaconda3\lib\site-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: six>=1.5.2 in c:\users\sce\anaconda3\lib\site-packages (from pyOpenSSL>=0.14->urllib3[secure,socks]~=1.26->selenium) (1.16.0)
# Collecting h11<1,>=0.9.0
#   Downloading h11-0.13.0-py3-none-any.whl (58 kB)
# Installing collected packages: outcome, h11, wsproto, trio, trio-websocket, selenium
# Successfully installed h11-0.13.0 outcome-1.2.0 selenium-4.3.0 trio-0.21.0 trio-websocket-0.9.2 wsproto-1.1.0
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Building wheels for collected packages: fake-useragent
#   Building wheel for fake-useragent (setup.py): started
#   Building wheel for fake-useragent (setup.py): finished with status 'done'
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=93540639438b3ac3ad5f09a19324d97afcc3476cff70739beb631e4fab528b89
#   Stored in directory: c:\users\sce\appdata\local\pip\cache\wheels\ae\e7\76\7dd44644d065268ab0e1b4fa2e802fa4bb0157717b7d6c6d92
# Successfully built fake-useragent
# Installing collected packages: fake-useragent
# Successfully installed fake-useragent-0.1.11

# %%
from bs4 import BeautifulSoup as bs
from lxml import html
from lxml import cssselect
import pymysql
import cursor
import requests
from selenium import webdriver
from urllib import parse
import json
import time,random
from fake_useragent import UserAgent

# %%
def exist(i):
    try:
        Pinfo[i] = infoJ[i]
    except:
        Pinfo[i] = "未提供"

# %%
key = []

total = requests.get("https://asms.coa.gov.tw/Asms/api/ViewNowAnimal?pageSize=10000&currentPage=1&sortDirection=DESC&sortFields=AcceptDate").text
totalJ = json.loads(total)

for i in totalJ:
    keyDict = {}
    keyDict["Id"] = i["AnimalId"]
    keyDict["AcceptNum"] = i["AcceptNum"]
    key.append(keyDict)

# %%
ua = UserAgent()

# %%
Ainfo = []

for i in key:
    try:
        Pinfo = {}
        user_agent = ua.random
        headers = {'user-agent': user_agent}
        info = requests.get("https://asms.coa.gov.tw/Asms/api/Animals?AcceptNum={}&keyNo={}&stChk=Y".format(i['AcceptNum'],i['Id']), headers=headers).text
        infoJ = json.loads(info)[0]
        exist("Name")
        exist("TypeIdName")
        exist("SexName")
        exist("VarietyName")
        exist("AcceptDate")
        exist("Age2Name")
        exist("ShelterName")
        exist("CoatName")
        exist("BuildName")
        exist("IsTNR")
        exist("HealthStatusName")
        Pinfo["city"] = Pinfo["ShelterName"][0:3]
        try:
            Pinfo["image_site"] = "https://asms.coa.gov.tw/Amlapp/Upload/Pic/" + infoJ["InImage"]
        except:
            Pinfo["image_site"] = "未提供"
        try:    
            Pinfo["url"] = "https://asms.coa.gov.tw/Amlapp/App/AnnounceList.aspx?Id={}&AcceptNum={}&PageType=Adopt".format(i['Id'],i['AcceptNum'])
        except:
            Pinfo["url"] = "未提供"
        Ainfo.append(Pinfo)
    except:
        print(i)
        continue
    time.sleep(3)
